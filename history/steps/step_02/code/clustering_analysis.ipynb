# %% [markdown]
# # Hierarchical Clustering Analysis
#
# **Initial Data Exploration**
#
# This notebook explores the methylation dataset in preparation for hierarchical clustering analysis.

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# ## Loading the Methylation Data
#
# The methylation dataset contains beta values for different cell types.

# %%
# Load the methylation CSV
df = pd.read_csv(
    "../data/methylation.csv",
    sep=";",
    decimal=","
)

print(f"Dataset shape: {df.shape}")
print(f"\nColumn names:")
print(df.columns.tolist())

# %% [markdown]
# ## Next Steps
#
# - Implement hierarchical clustering
# - Generate dendrograms
# - Compute distance metrics
